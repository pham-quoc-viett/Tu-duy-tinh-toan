# %%
w2a1

# %%
print("Hello World!")

# %%
w2a2

# %%
name = input("Enter your name: ")
print("Hello", name)

# %%
w2a3

# %%
a = int(input())
b = int(input())

print(a + b)          
print(a - b)          
print(a * b)          
print(a // b)         
print(a % b)          
print(f"{a / b:.2f}")

# %%
w2a4

# %%
a1, b1, c1, a2, b2, a3 = map(float, input().split())
average = ((a1 + b1 + c1) + (a2 + b2) * 2 + a3 * 3) / 10
print(f"{average:.1f}")

# %%
w2a5

# %%
a, b = map(int, input().split())
result = a ** b
print(result)

# %%
w2a6

# %%
char = input()
unicode_val = ord(char)
print(unicode_val)
upper_char = char.upper() 
print(upper_char)

# %%
w2a7

# %%
A = ((13 ** 2) * 3) + 5
B = 13 ** 2 * 3 + 5

print(A)
print(B)

# %%
w2a8

# %%
celsius = float(input("Enter Celsius: "))
fahrenheit = (9/5) * celsius + 32
print(f"{fahrenheit:.2f}")

# %%
w2a9

# %%
x = float(input("Enter watch price (USD): "))
shipping = 10
import_tax = 0.30 * x
vat = 0.10 * x
total = x + shipping + import_tax + vat
print(f"Total to pay: {total:.2f} USD")

# %%
w2a10

# %%
names = input("Nhập tên 3 người: ").split()
print(f"Hi {names[2]}, {names[1]} and {names[0]}.")

# %%
w2a11

# %%
h = int(input("Nhập số giờ: "))
m = int(input("Nhập số phút: "))

tong_giay = h * 3600 + m * 60
print(tong_giay)

# %%
w2a12

# %%
n = int(input("Nhập độ dài cạnh n: "))
tong_mieng_dan = 6 * (n**2)
print(tong_mieng_dan)

# %%
w2a13

# %%
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))

tich = a * b
hang_don_vi = tich % 10
print(hang_don_vi)

# %%
w2a14

# %%
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
a, b = b, a
print(f"Sau khi hoán đổi: a = {a}, b = {b}")

# %%
w2a15

# %%
n = int(input("Nhập n: "))
star_number = 6 * n * (n - 1) + 1
print(star_number)

# %%
w2a16

# %%
print("Spring\nSummer\nAutumn\nWinter")

# %%
w2a17

# %%
print("  * ")
print(" *** ")
print("*****")

# %%
w2a18

# %%
print("### ##   ### ###")
print("# # # #   #   # ")
print("#   # #   #   # ")
print("#   # #   #   # ")
print("#   ##    #   # ")

# %%
w2a19

# %%
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")

# %%
w2a20

# %%
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")

# %%
w2a21

# %%
for i in range(10):
    print("Hello, world")
